# %%
import numpy.random
numpy.random?

# %%
#print 5 uniformly distributed numbers b/n 0 and 1
print numpy.random.random(5)
print numpy.random.random(5)
# Out:
# [ 0.50839642  0.71384935  0.35938691  0.91374316  0.80352752]
# [ 0.78315143  0.75179712  0.85029117  0.98467846  0.93975099]

# %%
#set seed
numpy.random.seed(4242)
print "Using seed = 4242:"
print numpy.random.random(5)
# Out:
# Using seed = 4242:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
numpy.random.seed(None)
print "Using seed = None:"
print numpy.random.random(5)
# Out:
# Using seed = None:
# [ 0.58713123  0.44960657  0.67515326  0.36576751  0.42189057]

# %%
numpy.random.seed(4242)
print "Using seed = 4242, we should get the same numbers as before"
print numpy.random.random(5)
# Out:
# Using seed = 4242, we should get the same numbers as before
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
numpy.random.seed(None)
z = numpy.random.random(100000)
hist(z,100,normed=True)
plot([0,1.],[1.,1.],'r-',lw=3)
xlabel("x",fontsize=20)
ylabel("sample probability",fontsize=20)
show()

# %% [markdown]
# Example 1
# =

# %%
x = arange(0.,pi+0.001,0.01)
f = lambda x: sin(x)/2.
F = lambda x:(cos(0)-cos(x))/2.
        
plot(x,f(x),label = "True Distribution",lw=3)
plot(x,F(x),label = "Cumulative Function",lw=3)

xlim(0,3.5)
ylim(0,1.1)

legend(loc = 0)
show()

# %%
#number of samples
N = 10000

#number b/n 0 and 1
z = numpy.random.random_sample(N);

#inverse CDF
Finv = lambda z: arccos(cos(0)-2*z)
xsamples = Finv(z);

#compare to original
hist(xsamples,50,normed=True,label="Sampled Distribution")
plot(x,f(x),label="True Distribution",lw=3,color='red')

xlim(0,pi)
ylim(0,0.7)
legend(loc=0)
show()

# %% [markdown]
# Exercise 1
# =
# part a
# -

# %%
x = arange(0.,5.+.001,.001)
f = lambda x: e**(-x) 
F = lambda x: 1-e**(-x)

# %%
N = 10000
z = numpy.random.random_sample(N);
Finv = lambda z: -log(1-z) 
xsamples = Finv(z);

# %%
hist(xsamples,50,normed=True,label="Sampled Distribution")
plot(x,f(x),label="True Distribution",lw=3,color='red')
show()

# %% [markdown]
# part b
# =

# %%
plot(x,f(x),label = "True Distribution",lw=3)
plot(x,F(x),label = "Cumulative Function",lw=3)

xlim(0,5.)
ylim(-3.,3.)

legend(loc = 0)
show()

# %% [markdown]
# part c
# =

# %%
x = arange(0.,5.+.001,.001)
f = lambda x: e**(-x) 
F = lambda x: 1-e**(-x)
N = 10000
z = numpy.random.random_sample(N);
Finv = lambda z: -log(1-z) 
xsamples = Finv(z); 
hist(xsamples,50,normed=True,label="Sampled Distribution")
plot(x,f(x),label="True Distribution",lw=3,color='red')
show()

# %% [markdown]
# Exercise 2
# =
# part a
# -

# %%
b = f(x)
F = cumsum(b)/sum(b)
z = numpy.random.random_sample(N);
sort(F)
finv = x[searchsorted(F,z)]

# %%
x = arange(0.,5.+.001,.001)

N = 10000
z = numpy.random.random_sample(N); 
xsamples= finv; 
hist(xsamples,50,normed=True,label="Sampled Distribution")
plot(x,f(x),label="True Distribution",lw=3,color='red')
show()

# %%
def distribute1D(x,prob,N):
    b = prob
    F = cumsum(b)/sum(b)
    z = numpy.random.random_sample(N);
    sort(F)
    finv = x[searchsorted(F,z)]
    return finv

# %% [markdown]
# Exercise 3
# =
# part a
# -

# %%
dx = .001
x = arange(-0.2,0.201,dx)
a = 1e-5
d = 1.5e-5
lam = 632.8e-9
L = 1
IdsTotal = (sinc(a * x / (lam * L)))**2 * (cos(2 * pi * d*x/(lam*L)))**2
N = 10000
xsamples = distribute1D(x,IdsTotal,N) 

n,bins,patches = hist(xsamples,50,normed=True,label="Sampled Distribution")
plot(x,IdsTotal*max(n),label="True Distribution",lw=3,color='red')

show()
