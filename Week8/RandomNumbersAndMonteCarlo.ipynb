# %%
import numpy.random
numpy.random?

# %%
#print 5 uniformly distributed numbers b/n 0 and 1
print numpy.random.random(5)
print numpy.random.random(5)
# Out:
# [ 0.17682215  0.31398435  0.76972911  0.69652704  0.548645  ]
# [ 0.8584407   0.00389484  0.43501785  0.62482896  0.86677789]

# %%
#set seed
numpy.random.seed(4242)
print "Using seed = 4242:"
print numpy.random.random(5)
# Out:
# Using seed = 4242:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
numpy.random.seed(None)
print "Using seed = None:"
print numpy.random.random(5)
# Out:
# Using seed = None:
# [ 0.04172263  0.92959658  0.50584801  0.44575797  0.04072037]

# %%
numpy.random.seed(4242)
print "Using seed = 4242, we should get the same numbers as before"
print numpy.random.random(5)
# Out:
# Using seed = 4242, we should get the same numbers as before
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
numpy.random.seed(None)
z = numpy.random.random(100000)
hist(z,100,normed=True)
plot([0,1.],[1.,1.],'r-',lw=3)
xlabel("x",fontsize=20)
ylabel("sample probability",fontsize=20)
show()

# %% [markdown]
# Example 1
# =

# %%
x = arange(0.,pi+0.001,0.01)
f = lambda x: sin(x)/2.
F = lambda x:(cos(0)-cos(x))/2.
        
plot(x,f(x),label = "True Distribution",lw=3)
plot(x,F(x),label = "Cumulative Function",lw=3)

xlim(0,3.5)
ylim(0,1.1)

legend(loc = 0)
show()

# %%
#number of samples
N = 10000

#number b/n 0 and 1
z = numpy.random.random_sample(N);

#inverse CDF
Finv = lambda z: arccos(cos(0)-2*z)
xsamples = Finv(z);

#compare to original
hist(xsamples,50,normed=True,label="Sampled Distribution")
plot(x,f(x),label="True Distribution",lw=3,color='red')

xlim(0,pi)
ylim(0,0.7)
legend(loc=0)
show()

# %% [markdown]
# Exercise 1
# =
# part a
# -

# %%
x = arange(0.,5.+.001,.001)
f = lambda x: e**(-x) 
F = lambda x: 1-e**(-x)

# %%
N = 10000
z = numpy.random.random_sample(N);
Finv = lambda z: -log(1-z) 
xsamples = Finv(z);

# %%
hist(xsamples,50,normed=True,label="Sampled Distribution")
plot(x,f(x),label="True Distribution",lw=3,color='red')
show()

# %% [markdown]
# part b
# =

# %%
plot(x,f(x),label = "True Distribution",lw=3)
plot(x,F(x),label = "Cumulative Function",lw=3)

xlim(0,5.)
ylim(-3.,3.)

legend(loc = 0)
show()

# %% [markdown]
# part c
# =

# %%
x = arange(0.,5.+.001,.001)
f = lambda x: e**(-x) 
F = lambda x: 1-e**(-x)
N = 10000
z = numpy.random.random_sample(N);
Finv = lambda z: -log(1-z) 
xsamples = Finv(z); 
hist(xsamples,50,normed=True,label="Sampled Distribution")
plot(x,f(x),label="True Distribution",lw=3,color='red')
show()

# %% [markdown]
# Exercise 2
# =
# part a
# -

# %%
b = f(x)
F = cumsum(b)/sum(b)
z = numpy.random.random_sample(N);
sort(F)
searchsorted(z,F)
# Out:
# array([    0,     0,     0, ..., 10000, 10000, 10000])
