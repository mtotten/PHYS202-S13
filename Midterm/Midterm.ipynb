# %% [markdown]
# Question 2
# =
# part a.
# -

# %%
x = np.arange(-pi,pi,.1)
y = (cos(2*x) * cos(.5*x))**2

plot(x,y,'r')
xlabel("$\theta$$(rad)$")
ylabel("$intensity$")
xticks(arange(-pi, 5*pi/2, pi/2),('$-\pi$', '$-\pi/2$', '$-\pi/4$','$0$', '$+\pi/4$',  '$+\pi/2$', '$+\pi$', '$+3\pi/2$'))
show()

# %%
x = np.arange(-pi,pi,.1)
y = (cos(2*x) * cos(.5*x))**2

plot(x,y,'b*')
xlabel("$\theta$$(rad)$")
ylabel("$intensity$")
xticks(arange(-pi, 5*pi/2, pi/2),('$-\pi$', '$-\pi/2$', '$-\pi/4$','$0$', '$+\pi/4$',  '$+\pi/2$', '$+\pi$', '$+3\pi/2$'))
show()

# %% [markdown]
# part b.
# -

# %%
t = arange(-4.,4.1,.1)
#a = arange(-4.,-.1,.1)
#b = arange(.1,4.1,.1)
y = arange(-10.,10.,1.)
y = (1+t)/(t-1)
z = exp(-t)
plot(t,y,'b',label='(t+1)/(t-1)')
#plot(b,y,'b')
plot(t,z,'r.',label='exp(-t)')
legend(loc=3)
xticks(arange(-4, 6, 2),(-4, -2, 0, 2, 4))
#i wanted to plot each section of the function around the discontinuity and plot a vertical line at the point of discontinuity



xlabel('time(seconds)')
ylabel('f(t),g(t)')
show()

# %% [markdown]
# Question 3
# =
# part a.
# -

# %%
from Electrostatics import *
import scipy.integrate as integrate
q = 1e-19
x,y = arange(-5.,5.1,.1), arange(-5.,5.1,.1)
f = lambda x: pointField(x,y,q,3,3)

N = 1000 
a = 1.0
b = 2.0

h = (b-a)/N
s = f(a) + f(b)
for k in range (1,N/2 +1):
   s+= 4 * f(a + h*(2*k-1))
l = (.001*s) / 3
w = 0
for k in range (1, N/2):
    w += 2 * f(a + 2*k*h) 
b = (h*w) / 3   
print (l + b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-f7d694415b48> in <module>()
#      13 for k in range (1,N/2 +1):
#      14    s+= 4 * f(a + h*(2*k-1))
# ---> 15 l = (.001*s) / 3
#      16 w = 0
#      17 for k in range (1, N/2):
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# Question 4
# =
# part a.
# -

# %%
prefixes = 'JKLMNOPQ'
suffix = 'ack'

for letter in prefixes:
    if letter == 'O' or letter == 'Q':
        print letter + 'uack'
    else:    
        print letter + suffix
# Out:
# Jack
# Kack
# Lack
# Mack
# Nack
# Ouack
# Pack
# Quack

# %% [markdown]
# part b.
# -

# %%
def is_anagram(s1,s2):
    s1 = raw_input('word1')
    s2 = raw_input('word2')
    if len(str(s1)) == len(str(s2)):
        return "same length"
    else:
        return "not same length"
    if s1[:1] 
# about out of time but first i am making sure that the words are the same length. then i want to go through and compare each element of s1 to an element of s2 using a for loop
