# %% [markdown]
# Electric Dipole Equation
# =

# %% [markdown]
# \begin{equation}
# V(x,y) = \frac{kq}{\sqrt{x^2 + (y-d)^2}} - \frac{kq}{\sqrt{x^2 + (y+d)^2}}
# \end{equation}

# %%
#make x-y grid to cover the plane x and y b/n -2 and 2
dx = 0.06
dy = 0.06
x = arange(-2.,2.,dx)
y = arange(-2.,2.,dy)
print x.ndim
print len(x)

X,Y = meshgrid(x,y)
print X.ndim
print Y.shape
print X
print Y
# Out:
# 1
# 67
# 2
# (67, 67)
# [[-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  ...,
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]]
# [[-2.   -2.   -2.   ..., -2.   -2.   -2.  ]
#  [-1.94 -1.94 -1.94 ..., -1.94 -1.94 -1.94]
#  [-1.88 -1.88 -1.88 ..., -1.88 -1.88 -1.88]
#  ...,
#  [ 1.84  1.84  1.84 ...,  1.84  1.84  1.84]
#  [ 1.9   1.9   1.9  ...,  1.9   1.9   1.9 ]
#  [ 1.96  1.96  1.96 ...,  1.96  1.96  1.96]]

# %%
# make function V(x,y)
k = 1; q = 1; d= 1
V = (k*q/(X**2 + (Y - d)**2)**(1/2.)) - (k*q/(X**2 + (Y+d)**2)**(1/2.))
print V
# Out:
# [[-0.1698635  -0.17826925 -0.18715865 ..., -0.19336737 -0.18414007
#   -0.17541494]
#  [-0.17127992 -0.17998007 -0.18920149 ..., -0.19565471 -0.18606779
#   -0.17702367]
#  [-0.17245961 -0.18144664 -0.19099347 ..., -0.19768747 -0.18774672
#   -0.17839056]
#  ...,
#  [ 0.17310174  0.18227437  0.19203282 ...,  0.19888408  0.18871243
#    0.17915368]
#  [ 0.17209427  0.1809867   0.19042599 ...,  0.19704029  0.18721662
#    0.1779635 ]
#  [ 0.17083282  0.17943553  0.18854686 ...,  0.19491887  0.18545135
#    0.17651294]]

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d') #use these three lines for 3d graphs (from figure, get axis)
#help(Axes3D) #shows how stride and stuff change your graph
p = ax.plot_surface(X,Y,V, rstride=1, cstride=1, linewidth=0, cmap=cm.terrain) #hit tab after cm. to get list of colors
cb = fig.colorbar(p,shrink=.5)
show()

# %%
#3D data represented as contours
levels = array([8,4,2,1,.5,.25,0,-.25,-.5,-1,-2,-4,-8]) #divide by two each time...
contour(X,Y,V, levels, linewidths=5,cmap=cm.gist_rainbow)
show()

# %%
#Exercise 1:

dx = 12./51.
dy = 12./51.
x = arange(-6.,6.,dx)
y = arange(-6.,6.,dy)
X,Y = meshgrid(x,y)
G = exp(-X**2 - Y**2)
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
w = ax.plot_surface(X,Y,G, rstride=1, cstride=1, linewidth=0, cmap=cm.gist_stern)
cb = fig.colorbar(w,shrink=.5)
cset = ax.contour(X,Y,G,array([0.,0.2,0.4,0.6,0.8]),zdir ='x', offset = -6., cmap=cm.gist_stern_r)
show()

# %%
#Exercise 2
dx = 8./101.
dy = 8./101.
x = arange(-4.,4.,dx)
y = arange(-4.,4.,dy)
k = 8.85418782 #Nm^2/c^2 
q = 10**-9 #coulombs
d = 2       #meters
V = (k*q/(X**2 + (Y - d)**2)**(1/2.)) + (k*q/(X**2 + (Y + d)**2)**(1/2.))
U = -(k*q/(Y**2 + (X + d)**2)**(1/2.)) - (k*q/(Y**2 + (X - d)**2)**(1/2.))
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
w = ax.plot_surface(X,Y,V+U, rstride=1, cstride=1, linewidth=0, cmap=cm.Paired)

cb = fig.colorbar(w, shrink=.5)

show()

# %%
def pointPotential(x,y,q,posx,posy):
    k = 8.85418782
    q=1e-19 #define k and q
    
    Vxy = (k*q/((X-posx)**2 + (Y - posy)**2))**(1/2.) #replace the d with posx and posy; only use first term in dipole equation
    return Vxy

x = 1.; y = 1.
V11 = pointPotential(x,y,1e-9,0.,0.)
print V11
# Out:
# [[  1.10894017e-10   1.13089282e-10   1.15324280e-10 ...,   1.17595439e-10
#     1.15324280e-10   1.13089282e-10]
#  [  1.13089282e-10   1.15420304e-10   1.17799332e-10 ...,   1.20223007e-10
#     1.17799332e-10   1.15420304e-10]
#  [  1.15324280e-10   1.17799332e-10   1.20331806e-10 ...,   1.22918673e-10
#     1.20331806e-10   1.17799332e-10]
#  ...,
#  [  1.17595439e-10   1.20223007e-10   1.22918673e-10 ...,   1.25679886e-10
#     1.22918673e-10   1.20223007e-10]
#  [  1.15324280e-10   1.17799332e-10   1.20331806e-10 ...,   1.22918673e-10
#     1.20331806e-10   1.17799332e-10]
#  [  1.13089282e-10   1.15420304e-10   1.17799332e-10 ...,   1.20223007e-10
#     1.17799332e-10   1.15420304e-10]]

# %%
def dipolePotential(x,y,q,d):
    k = 8.85418782
    q=1e-19
    V = (k*q/(X**2 + (Y - d/2)**2)**(1/2.)) - (k*q/(X**2 + (Y+d/2)**2)**(1/2.)) #replace with d/2 since from origin to singular particle is d/2
    U = -(k*q/(Y**2 + (X + d/2)**2)**(1/2.)) - (k*q/(Y**2 + (X - d/2)**2)**(1/2.))
    Vxy = U + V #sum up the functions
    return Vxy

# %%
q=1e-19
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
w = ax.plot_surface(X,Y,pointPotential(x,y,q,0.,0.), rstride=1, cstride=1, linewidth=0, cmap=cm.gist_stern)
cb = fig.colorbar(w,shrink=.5)

# %%
q=1e-19
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
w = ax.plot_surface(X,Y,dipolePotential(x,y,q,1.0), rstride=1, cstride=1, linewidth=0, cmap=cm.gist_stern)
cb = fig.colorbar(w,shrink=.5)
