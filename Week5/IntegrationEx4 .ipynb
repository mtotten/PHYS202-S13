# %% [markdown]
# Question 1
# =
# part a
# -

# %%
f = lambda x: e** (-x**2)

# %%
N = 10 
a = 0.0
b = 3.0

h = (b-a)/N
s = f(a) + f(b)
for k in range (1,N/2 +1):
   s+= 4 * f(a + h*(2*k-1))
l = (h*s) / 3
w = 0
for k in range (1, N/2):
    w += 2 * f(a + 2*k*h) 
b = (h*w) / 3   
print (l + b)
# Out:
# 0.886206552246

# %% [markdown]
# part b.
# -

# %%
import numpy as np
x = arange(0., 3.1,.1)
q = zeros(shape(x),float)
import scipy.integrate as integrate
for i in range(1,len(x)):
    q[i] = integrate.simps(x[:i],f(x[:i]))
plot(x,q,'r')
show()

# %% [markdown]
# Question 2
# =
# part a.
# -

# %%
L = 1.
N = 1.
f = lambda x: (2./L) * (sin(N*x*pi/L))**2
x = arange(L/3.,L/2.+.01,.01)
a = integrate.trapz(f(x),x)
print a
# Out:
# 0.311118868918

# %%
L = 1.
N = 1.
f = lambda x: (2./L) * (sin(N*x*pi/L))**2
x = arange(L/3.,L/2.+.1,.001)
a, error = integrate.quad(f,L/3.,L/2.)
print a
# Out:
# 0.304498890522

# %% [markdown]
# part b.
# -

# %%
c = arange(0.,1.01,.01)
plot(c,f(c))
y = lambda x: 2. * (sin(2*x*pi))**2
plot(c,y(c))
show()

# %% [markdown]
# Question 3
# =

# %%
def H(n,x):
    Hminus1= 0 *x
    H=1 + 0*x
    for a in (0,n):
        d = 2*x*H - 2*a*Hminus1
        Hminus1 = H
        H = d
    return H    
from math import *
si = lambda n,x: 1/((2.**n*factorial(n)*(pi**.5))**.5)*exp(-x**2./2.)*H(n,x)
x = arange(-4.,4.1,.1)    
plot(x,si(0,x),label = 'n=0')
plot(x,si(1,x),label = 'n=1')
plot(x,si(2,x),label = 'n=2')
plot(x,si(3,x),label = 'n=3')
legend()
show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-fa29fcfe12ac> in <module>()
#      10 si = lambda n,x: 1/((2.**n*factorial(n)*(pi**.5))**.5)*exp(-x**2./2.)*H(n,x)
#      11 x = arange(-4.,4.1,.1)
# ---> 12 plot(x,si(0,x),label = 'n=0')
#      13 plot(x,si(1,x),label = 'n=1')
#      14 plot(x,si(2,x),label = 'n=2')
#
# <ipython-input-13-fa29fcfe12ac> in <lambda>(n, x)
#       8     return H
#       9 from math import *
# ---> 10 si = lambda n,x: 1/((2.**n*factorial(n)*(pi**.5))**.5)*exp(-x**2./2.)*H(n,x)
#      11 x = arange(-4.,4.1,.1)
#      12 plot(x,si(0,x),label = 'n=0')
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %% [markdown]
# Question 4
# =

# %%
f = lambda x: 4 * (1-x**2)**.5
    
x = arange(0.,1.1,0.001)

xmin = 0.
xmax = 1.
subx = x[logical_and((x>xmin),(x<xmax))]
ymax = max(f(subx))
ymin = 0.

N = 10000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

newmask = (samples_y < f(samples_x))
sum(newmask)

Iana = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask
Iexact = pi
Ierr = 100 * (Iexact-Iana)/Iexact
print "I_exact=",Iexact
print "I_hitormiss=",Iana
print "Error on I =",Ierr,"%"
# Out:
#  I_exact= 3.14159265359
# I_hitormiss= [ 31495.984252  31495.984252  31495.984252 ...,  31495.984252  31495.984252
#   31495.984252]
# Error on I = [-1002448.31624993 -1002448.31624993 -1002448.31624993 ...,
#  -1002448.31624993 -1002448.31624993 -1002448.31624993] %
