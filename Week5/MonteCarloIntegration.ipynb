# %% [markdown]
# Exercise 1
# =

# %%
f = lambda x: x**(0.5) + sin(x)

# %%
x = arange(0.,15.,0.001)

# %%
myplot = plot(x,f(x),lw=3)
ylabel(r'$x^{1/2} + \sin(x)$',fontsize=20)
xlabel(r'$x$',fontsize=20)
xlim(0.,15.)
show()

# %%
xmin = 1.7
xmax = 12.4
subx = x[logical_and((x>xmin),(x<xmax))]
ymax = max(f(subx))*1.05
ymin = 0.
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)
plot([xmin,xmin],[ymin,ymax],color='k', linestyle="--")
plot([xmax,xmax],[ymin,ymax],color='k', linestyle="--")
plot([xmin,xmax],[ymax,ymax],color='k', linestyle="--")
show()

# %%
N = 10000000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:300],samples_y[1:300],'.')

plot([xmin,xmin],[ymin,ymax],color='k',linestyle='--')
plot([xmax,xmax],[ymin,ymax],color='k',linestyle='--')
plot([xmin,xmax],[ymax,ymax],color='k',linestyle='--')

show()

# %%
newmask = (samples_y < f(samples_x))

# %%
sum(newmask)
# Out:
# 6180859

# %%
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')
plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')

plot([xmin,xmin],[ymin,ymax],color='k',linestyle='--')
plot([xmax,xmax],[ymin,ymax],color='k',linestyle='--')
plot([xmin,xmax],[ymax,ymax],color='k',linestyle='--')

show()

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.5148466546

# %%
Iana = lambda x:(2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100 * (Iexact-I)/Iexact
print "I_exact=",Iexact
print "I_hitormiss=",I
print "Error on I =",Ierr,"%"
# Out:
# I_exact= 26.5172145362
# I_hitormiss= 26.5148466546
# Error on I = 0.00892960151353 %

# %% [markdown]
# For this sampling, I tried ten million points. This gets an error of .05%. Adding more N points does not decrease the error dramatically and there are some limits on how many data points the kernel can handle.

# %% [markdown]
# Exercise 2
# =
# part a.
# -

# %%
f = lambda x: x**(0.5) + sin(x)
    
x = arange(0.,15.,0.001)

xmin = 1.7
xmax = 12.4
subx = x[logical_and((x>xmin),(x<xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

N = 10000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

newmask = (samples_y < f(samples_x))
sum(newmask)

Iana = lambda x:(2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100 * (Iexact-I)/Iexact
print "I_exact=",Iexact
print "I_hitormiss=",I
print "Error on I =",Ierr,"%"
# Out:
# I_exact= 26.5172145362
# I_hitormiss= 26.5148466546
# Error on I = 0.00892960151353 %

# %%
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)
N = 10000
a = (xmax-xmin)
s = 0

for i in range(N):
    s +=(f(xmin + (xmax-xmin)*random_sample()))
b = s / N
print b

y = zeros(x.shape,float)
y[:] = b
print y
plot(samples_x[1:200],samples_y[1:200],'.')
plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')
plot(x,y)
plot([xmin,xmin],[ymin,ymax],color='k',linestyle='--')
plot([xmax,xmax],[ymin,ymax],color='k',linestyle='--')
plot([xmin,xmax],[ymax,ymax],color='k',linestyle='--')

show()
# Out:
# 2.4732428779
# [ 2.47324288  2.47324288  2.47324288 ...,  2.47324288  2.47324288
#   2.47324288]

# %%
fxyz = lambda x,y,z: sqrt(x**2 + y*
